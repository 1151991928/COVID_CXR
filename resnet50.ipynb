# %%
import numpy as np
import cv2 as cv
import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader,Dataset
import os
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import torchvision.models as models

# %%
class mydataset(Dataset):
    def __init__(self, path,transform=None):
        filenames=[]
        labels1 = []
        labels2 = []
        with open(path, 'r') as file:
            for line in file:
                parts = line.strip().split()  # 移除行尾的换行符并按空格分割
                filename = parts[0]
                label1 = int(parts[1])
                label2 = int(parts[2])
                filenames.append(filename)
                labels1.append(label1)
                labels2.append(label2)
        mapping = {
                            '00': 0,
                            '10': 1,
                            '11': 2,
                            '01': 3
                        }        
        combined_labels_str = np.core.defchararray.add(np.array(labels1).astype(str), np.array(labels2).astype(str))
        new_combined_labels = np.vectorize(mapping.get)(combined_labels_str)
        self.all_image_paths = filenames
        self.all_image_labels = new_combined_labels
        self.transform=transform

    def __getitem__(self, index):
        img = Image.open('images_jpegs_255/'+self.all_image_paths[index]).convert('RGB')
        img=self.transform(img)
        label=self.all_image_labels[index]
        label=torch.tensor(label,dtype=torch.float32)
        return img, label

    def __len__(self):
        return len(self.all_image_paths)

# %%
data_transforms = transforms.Compose([
    transforms.Resize(256),    # 将图片短边缩放至256，长宽比保持不变：
    transforms.CenterCrop(224),   #将图片从中心切剪成3*224*224大小的图片
    transforms.ToTensor()          #把图片进行归一化，并把数据转换成Tensor类型
])

# %%
train_data=mydataset('train.txt',data_transforms)
test_data=mydataset('test.txt',data_transforms)
train_dataloader=DataLoader(train_data,batch_size=64,shuffle=True)
test_dataloader=DataLoader(test_data,batch_size=64,shuffle=True)

train_data_size=len(train_data)
test_data_size=len(test_data)

# %%
resnet50 = models.resnet50(pretrained=True)
num_ftrs = resnet50.fc.in_features 

 
#保持in_features不变，修改out_features=4
resnet50.fc = nn.Sequential(nn.Linear(num_ftrs,4),
                            
                            
                
                            nn.LogSoftmax(dim=1))
# Out:
# c:\Users\armstrong\.conda\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\armstrong\.conda\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model=resnet50
model.cuda()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=4, bias=True)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %%
#损失函数和优化器
loss_fn=nn.CrossEntropyLoss()
loss_fn=loss_fn.cuda()
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
total_train_step=0
total_test_step=0
for i in range(100):
    print('第{}轮训练'.format(i+1))
    model.train()
    for data in train_dataloader:
        imgs,targets=data
        targets=targets.long()
        imgs=imgs.cuda()
        targets=targets.cuda()
        outputs=model(imgs)
        loss=loss_fn(outputs,targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_train_step=total_train_step+1
    
    model.eval()
    total_test_loss=0
    total_accuracy=0
    with torch.no_grad():
        for data in test_dataloader:
            imgs,targets=data
            imgs=imgs.cuda()
            targets=targets.long()
            targets=targets.cuda()
            outputs=model(imgs)
            loss=loss_fn(outputs,targets)
            total_test_loss=total_test_loss+loss
            accuracy=(outputs.argmax(1)==targets).sum()
            total_accuracy=total_accuracy+accuracy
    print("整体测试集上的Loss:{}".format(total_test_loss))
    print('测试集上的正确率:{}'.format(total_accuracy/test_data_size))
    total_test_step=total_test_step+1

torch.save(model,'resnet50.pth')
# Out:
# 第1轮训练
# 整体测试集上的Loss:2.237412452697754
# 测试集上的正确率:0.48181816935539246
# 第2轮训练
# 整体测试集上的Loss:2.3127427101135254
# 测试集上的正确率:0.29999998211860657
# 第3轮训练
# 整体测试集上的Loss:1.865556240081787
# 测试集上的正确率:0.5909090638160706
# 第4轮训练
# 整体测试集上的Loss:1.941279649734497
# 测试集上的正确率:0.5272727012634277
# 第5轮训练
# 整体测试集上的Loss:1.855771780014038
# 测试集上的正确率:0.5636363625526428
# 第6轮训练
# 整体测试集上的Loss:1.8276619911193848
# 测试集上的正确率:0.5181818008422852
# 第7轮训练
# 整体测试集上的Loss:1.7221548557281494
# 测试集上的正确率:0.5727272629737854
# 第8轮训练
# 整体测试集上的Loss:2.2671217918395996
# 测试集上的正确率:0.49090906977653503
# 第9轮训练
# 整体测试集上的Loss:3.181499481201172
# 测试集上的正确率:0.29999998211860657
# 第10轮训练
# 整体测试集上的Loss:1.8783330917358398
# 测试集上的正确率:0.581818163394928
# 第11轮训练
# 整体测试集上的Loss:2.157015800476074
# 测试集上的正确率:0.5181818008422852
# 第12轮训练
# 整体测试集上的Loss:2.0392510890960693
# 测试集上的正确率:0.5909090638160706
# 第13轮训练
# 整体测试集上的Loss:1.8036465644836426
# 测试集上的正确率:0.6363636255264282
# 第14轮训练
# 整体测试集上的Loss:2.1366117000579834
# 测试集上的正确率:0.581818163394928
# 第15轮训练
# 整体测试集上的Loss:2.082535982131958
# 测试集上的正确率:0.6454545259475708
# 第16轮训练
# 整体测试集上的Loss:2.2291197776794434
# 测试集上的正确率:0.5636363625526428
# 第17轮训练
# 整体测试集上的Loss:2.2170770168304443
# 测试集上的正确率:0.5999999642372131
# 第18轮训练
# 整体测试集上的Loss:2.094632148742676
# 测试集上的正确率:0.5636363625526428
# 第19轮训练
# 整体测试集上的Loss:2.213186025619507
# 测试集上的正确率:0.5999999642372131
# 第20轮训练
# 整体测试集上的Loss:2.2016665935516357
# 测试集上的正确率:0.5909090638160706
# 第21轮训练
# 整体测试集上的Loss:2.1660470962524414
# 测试集上的正确率:0.6363636255264282
# 第22轮训练
# 整体测试集上的Loss:2.2045342922210693
# 测试集上的正确率:0.5545454621315002
# 第23轮训练
# 整体测试集上的Loss:2.243149995803833
# 测试集上的正确率:0.6181818246841431
# 第24轮训练
# 整体测试集上的Loss:2.3231935501098633
# 测试集上的正确率:0.5999999642372131
# 第25轮训练
# 整体测试集上的Loss:2.2558484077453613
# 测试集上的正确率:0.6090908646583557
# 第26轮训练
# 整体测试集上的Loss:2.409782886505127
# 测试集上的正确率:0.581818163394928
# 第27轮训练
# 整体测试集上的Loss:2.2590579986572266
# 测试集上的正确率:0.5909090638160706
# 第28轮训练
# 整体测试集上的Loss:2.202956199645996
# 测试集上的正确率:0.6272727251052856
# 第29轮训练
# 整体测试集上的Loss:2.451115608215332
# 测试集上的正确率:0.6454545259475708
# 第30轮训练
# 整体测试集上的Loss:2.528384208679199
# 测试集上的正确率:0.581818163394928
# 第31轮训练
# 整体测试集上的Loss:2.1296074390411377
# 测试集上的正确率:0.6181818246841431
# 第32轮训练
# 整体测试集上的Loss:2.4588730335235596
# 测试集上的正确率:0.6272727251052856
# 第33轮训练
# 整体测试集上的Loss:2.490940570831299
# 测试集上的正确率:0.6454545259475708
# 第34轮训练
# 整体测试集上的Loss:2.290895938873291
# 测试集上的正确率:0.6272727251052856
# 第35轮训练
# 整体测试集上的Loss:2.718843460083008
# 测试集上的正确率:0.5363636016845703
# 第36轮训练
# 整体测试集上的Loss:2.466468334197998
# 测试集上的正确率:0.6090908646583557
# 第37轮训练
# 整体测试集上的Loss:2.364555835723877
# 测试集上的正确率:0.6090908646583557
# 第38轮训练
# 整体测试集上的Loss:2.4174277782440186
# 测试集上的正确率:0.581818163394928
# 第39轮训练
# 整体测试集上的Loss:2.418039321899414
# 测试集上的正确率:0.6545454263687134
# 第40轮训练
# 整体测试集上的Loss:2.4499118328094482
# 测试集上的正确率:0.6363636255264282
# 第41轮训练
# 整体测试集上的Loss:2.434025287628174
# 测试集上的正确率:0.6454545259475708
# 第42轮训练
# 整体测试集上的Loss:2.541189193725586
# 测试集上的正确率:0.6090908646583557
# 第43轮训练
# 整体测试集上的Loss:2.5346121788024902
# 测试集上的正确率:0.5999999642372131
# 第44轮训练
# 整体测试集上的Loss:2.3888890743255615
# 测试集上的正确率:0.5727272629737854
# 第45轮训练
# 整体测试集上的Loss:2.4582715034484863
# 测试集上的正确率:0.6272727251052856
# 第46轮训练
# 整体测试集上的Loss:2.376471996307373
# 测试集上的正确率:0.6181818246841431
# 第47轮训练
# 整体测试集上的Loss:2.4060287475585938
# 测试集上的正确率:0.5636363625526428
# 第48轮训练
# 整体测试集上的Loss:2.4146785736083984
# 测试集上的正确率:0.6454545259475708
# 第49轮训练
# 整体测试集上的Loss:2.554398536682129
# 测试集上的正确率:0.5999999642372131
# 第50轮训练
# 整体测试集上的Loss:2.350618839263916
# 测试集上的正确率:0.6545454263687134
# 第51轮训练
# 整体测试集上的Loss:2.564584732055664
# 测试集上的正确率:0.6454545259475708
# 第52轮训练
# 整体测试集上的Loss:2.672863721847534
# 测试集上的正确率:0.6454545259475708
# 第53轮训练
# 整体测试集上的Loss:2.673798084259033
# 测试集上的正确率:0.6181818246841431
# 第54轮训练
# 整体测试集上的Loss:2.5794739723205566
# 测试集上的正确率:0.6181818246841431
# 第55轮训练
# 整体测试集上的Loss:2.4295735359191895
# 测试集上的正确率:0.6181818246841431
# 第56轮训练
# 整体测试集上的Loss:2.496242046356201
# 测试集上的正确率:0.6545454263687134
# 第57轮训练
# 整体测试集上的Loss:2.455979824066162
# 测试集上的正确率:0.581818163394928
# 第58轮训练
# 整体测试集上的Loss:2.635070323944092
# 测试集上的正确率:0.6272727251052856
# 第59轮训练
# 整体测试集上的Loss:2.678062677383423
# 测试集上的正确率:0.6272727251052856
# 第60轮训练
# 整体测试集上的Loss:2.532158613204956
# 测试集上的正确率:0.5909090638160706
# 第61轮训练
# 整体测试集上的Loss:2.6487135887145996
# 测试集上的正确率:0.5636363625526428
# 第62轮训练
# 整体测试集上的Loss:2.6708521842956543
# 测试集上的正确率:0.5727272629737854
# 第63轮训练
# 整体测试集上的Loss:2.546273708343506
# 测试集上的正确率:0.6454545259475708
# 第64轮训练
# 整体测试集上的Loss:2.573610305786133
# 测试集上的正确率:0.5909090638160706
# 第65轮训练
# 整体测试集上的Loss:2.453640937805176
# 测试集上的正确率:0.5727272629737854
# 第66轮训练
# 整体测试集上的Loss:2.5208888053894043
# 测试集上的正确率:0.6363636255264282
# 第67轮训练
# 整体测试集上的Loss:2.5487864017486572
# 测试集上的正确率:0.6363636255264282
# 第68轮训练
# 整体测试集上的Loss:2.631948947906494
# 测试集上的正确率:0.5999999642372131
# 第69轮训练
# 整体测试集上的Loss:2.6840219497680664
# 测试集上的正确率:0.6272727251052856
# 第70轮训练
# 整体测试集上的Loss:2.4664406776428223
# 测试集上的正确率:0.6272727251052856
# 第71轮训练
# 整体测试集上的Loss:2.5212979316711426
# 测试集上的正确率:0.581818163394928
# 第72轮训练
# 整体测试集上的Loss:2.6680350303649902
# 测试集上的正确率:0.6363636255264282
# 第73轮训练
# 整体测试集上的Loss:2.6504483222961426
# 测试集上的正确率:0.6363636255264282
# 第74轮训练
# 整体测试集上的Loss:2.622386932373047
# 测试集上的正确率:0.6363636255264282
# 第75轮训练
# 整体测试集上的Loss:2.589505195617676
# 测试集上的正确率:0.581818163394928
# 第76轮训练
# 整体测试集上的Loss:2.507462501525879
# 测试集上的正确率:0.6181818246841431
# 第77轮训练
# 整体测试集上的Loss:2.6594057083129883
# 测试集上的正确率:0.6545454263687134
# 第78轮训练
# 整体测试集上的Loss:2.911564826965332
# 测试集上的正确率:0.6363636255264282
# 第79轮训练
# 整体测试集上的Loss:2.7409839630126953
# 测试集上的正确率:0.6090908646583557
# 第80轮训练
# 整体测试集上的Loss:2.638160228729248
# 测试集上的正确率:0.5999999642372131
# 第81轮训练
# 整体测试集上的Loss:2.642033576965332
# 测试集上的正确率:0.581818163394928
# 第82轮训练
# 整体测试集上的Loss:2.654465675354004
# 测试集上的正确率:0.6545454263687134
# 第83轮训练
# 整体测试集上的Loss:2.689525604248047
# 测试集上的正确率:0.6454545259475708
# 第84轮训练
# 整体测试集上的Loss:2.603116989135742
# 测试集上的正确率:0.6181818246841431
# 第85轮训练
# 整体测试集上的Loss:2.6847991943359375
# 测试集上的正确率:0.5999999642372131
# 第86轮训练
# 整体测试集上的Loss:2.506375312805176
# 测试集上的正确率:0.6272727251052856
# 第87轮训练
# 整体测试集上的Loss:2.674586772918701
# 测试集上的正确率:0.6454545259475708
# 第88轮训练
# 整体测试集上的Loss:2.1321167945861816
# 测试集上的正确率:0.5999999642372131
# 第89轮训练
# 整体测试集上的Loss:2.7590837478637695
# 测试集上的正确率:0.6090908646583557
# 第90轮训练
# 整体测试集上的Loss:2.629392385482788
# 测试集上的正确率:0.581818163394928
# 第91轮训练
# 整体测试集上的Loss:2.668703079223633
# 测试集上的正确率:0.6454545259475708
# 第92轮训练
# 整体测试集上的Loss:2.6344432830810547
# 测试集上的正确率:0.5999999642372131
# 第93轮训练
# 整体测试集上的Loss:2.848055124282837
# 测试集上的正确率:0.6181818246841431
# 第94轮训练
# 整体测试集上的Loss:2.557551860809326
# 测试集上的正确率:0.6090908646583557
# 第95轮训练
# 整体测试集上的Loss:2.5994040966033936
# 测试集上的正确率:0.6272727251052856
# 第96轮训练
# 整体测试集上的Loss:2.6069412231445312
# 测试集上的正确率:0.6272727251052856
# 第97轮训练
# 整体测试集上的Loss:2.7612297534942627
# 测试集上的正确率:0.6454545259475708
# 第98轮训练
# 整体测试集上的Loss:2.686124801635742
# 测试集上的正确率:0.581818163394928
# 第99轮训练
# 整体测试集上的Loss:2.762734889984131
# 测试集上的正确率:0.6090908646583557
# 第100轮训练
# 整体测试集上的Loss:2.7581467628479004
# 测试集上的正确率:0.6090908646583557

# %%
def predict(model,path):
    img=Image.open(path).convert("RGB")
    img=data_transforms(img)
    img = img.unsqueeze(0).repeat(1, 1, 1, 1)
    output=model(img.cuda())
    _, predicted = torch.max(output.data, 1)
    return predicted

# %%
a=predict(model,'C:/Users/armstrong/Desktop/sth/CXR-数据集（中意）/COVID_CXR意大利/COVID_CXR/images_jpegs_255/P_787.jpeg')
a
# Out:
# tensor([1], device='cuda:0')
